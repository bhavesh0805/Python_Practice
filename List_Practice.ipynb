# %%
# Deep indexing Practice

# %%
#•	Task: Write the code to extract the word "target".
data = ["a", "b", ["c", ["d", "e", "target"], "f"], "g"]
data[2][1][2]
# Out:
# 'target'

# %% [raw]
# Append vs. Extend Given: colors = ["red", "blue"]
# •	Task A: Add the list ["green", "yellow"] so the result is ['red', 'blue', ['green', 'yellow']].
# •	Task B: Add the same list so the result is ['red', 'blue', 'green', 'yellow'].

# %%
colors = ["red", "blue"]
Colors = ["green", "yellow"]
colors.append(Colors)

# %%
colors
# Out:
# ['red', 'blue', ['green', 'yellow']]

# %%
colors = ["red", "blue"]

# %%
colors
# Out:
# ['red', 'blue']

# %%
colors.extend(Colors)

# %%
colors
# Out:
# ['red', 'blue', 'green', 'yellow']

# %% [raw]
# 3. Matrix Access Matrices are often represented as nested lists: matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# •	Task: Access the number 6.

# %%
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
matrix[1][2]
# Out:
# 6

# %% [raw]
# . Using .insert() Given: nums = [10, 20, 40]
# •	Task: Insert the number 30 at the correct spot to keep the list numerical.

# %%
nums = [10, 20, 40]
nums.insert(2,30)

# %%
nums
# Out:
# [10, 20, 30, 40]

# %% [raw]
# 4. Mixed Data Types Given: mixed = [1, "Python", [True, False]]
# •	Task: Change False to None.

# %%
mixed = [1, "Python", [True, False]]
mixed[2][1] = 'none'

# %%
mixed
# Out:
# [1, 'Python', [True, 'none']]

# %% [markdown]
# # Part 1: Nested List Indexing

# %%
nested = [1, [2, 3, [4, 5, 6]], 7]
nested[1][0]
# Out:
# 2

# %%
nested[1][2]
# Out:
# [4, 5, 6]

# %%
nested[1][2][1]
# Out:
# 5

# %%
matrix = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]
matrix[1]
# Out:
# [40, 50, 60]

# %%
matrix[2][2]
# Out:
# 90

# %%
matrix[1][0]
# Out:
# 40

# %% [markdown]
# # Part 2: List Methods (append, extend, insert)

# %% [raw]
# Using insert() Given nums = [10, 20, 40, 50].
# •	Task: Insert 30 at the correct numerical position.

# %%
nums = [10, 20, 40, 50]
nums.insert(2,30)

# %%
nums
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# # Part 3: Advanced Practice Challenges
